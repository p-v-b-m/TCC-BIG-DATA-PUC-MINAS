# %%
import pandas as pd
import numpy as np

# %%
# fazendo a leitura da base enriquecida, trabalhada na etapa anterior
df = pd.read_csv("base_enriquecida_codigos")

# %%
df
# Out:
#          ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0        2019-12  85044021       11      249        SP       4  817700
# 1        2019-12  85183000       11      160        GO       4  817600
# 2        2019-12  39263000       10       23        SP       1  817800
# 3        2019-12  38249929       10      493        SP       1  817800
# 4        2019-12  34021300       10      493        BA       1  517800
# ...          ...       ...      ...      ...       ...     ...     ...
# 1764428  2019-08  85365090       11      271        SP       4  817600
# 1764429  2019-08  30043918       10      767        SP       4  817600
# 1764430  2019-08  90189099       11       87        SP       1  817800
# 1764431  2019-08  84123900       11      764        PA       4  817600
# 1764432  2019-08  85269200       11      776        SP       4  817600
#
#          QT_ESTAT  KG_LIQUIDO   VL_FOB  câmbio_mês_atual  câmbio_mês_anterior
# 0              53          44     8263          4.108924             4.154725
# 1           23734        1621     6987          4.108924             4.154725
# 2            3951        3951    88311          4.108924             4.154725
# 3           19540       19540    65812          4.108924             4.154725
# 4           34400       34400   119356          4.108924             4.154725
# ...           ...         ...      ...               ...                  ...
# 1764428        11         157     4412          4.019382             3.778713
# 1764429       225         225  1216801          4.019382             3.778713
# 1764430      5033         178    22889          4.019382             3.778713
# 1764431         1          83     7641          4.019382             3.778713
# 1764432         2           0      119          4.019382             3.778713
#
# [1764433 rows x 12 columns]

# %% [markdown]
# ###### Checando posições NCM recorrentes

# %% [markdown]
# Por meio do Jupyer Notebook "03_análises_diversas_e_representações_gráficas - PARTE 01", constata-se que a maior quantidade de mercadoria importada classifica-se na posição 8532. De todo modo, para fins de implementação do modelo, entende-se que é desejável não apenas um código que tenha sido importado em quantidade, mas, sobretudo, que tenha sido recorrente. Segue, portanto, consulta à posição da NCM em que os códigos NCM foram mais recorrentes.

# %%
# testa capítulos mais recorrentes
df["POSIÇÃO_NCM"] = df["CO_NCM"].astype(str).str[:4]

# %%
df["POSIÇÃO_NCM"].value_counts().head(10)
# Out:
# 8708    51461
# 8536    43444
# 8481    36563
# 8483    35341
# 7318    34623
# 8504    25489
# 8421    24525
# 9032    24435
# 8541    24434
# 8482    24306
# Name: POSIÇÃO_NCM, dtype: int64

# %%
# teste 0
df[df["POSIÇÃO_NCM"]=="8708"]["CO_UNID"].value_counts()
# Out:
# 11    40809
# 10    10652
# Name: CO_UNID, dtype: int64

# %%
# teste 1
df[df["POSIÇÃO_NCM"]=="8536"]["CO_UNID"].value_counts()
# Out:
# 11    43444
# Name: CO_UNID, dtype: int64

# %%
# teste 3
df[df["POSIÇÃO_NCM"]=="8504"]["CO_UNID"].value_counts()
# Out:
# 11    22498
# 10     2991
# Name: CO_UNID, dtype: int64

# %%
df["CO_UNID"].value_counts()
# Out:
# 10    978971
# 11    760161
# 13      8616
# 15      5962
# 17      5704
# 16      2221
# 21      1671
# 19       457
# 12       297
# 22       170
# 20       149
# 14        35
# 18        19
# Name: CO_UNID, dtype: int64

# %%
# no caso em questão será selecionada a 7318, pois, embora seja a 5ª na lista acima, é a primeira se levarmos em conta a
df1=df[df["POSIÇÃO_NCM"]=="7318"]

# %%
df1
# Out:
#          ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 8        2019-12  73181500       10       23        SP       4  817700
# 13       2019-12  73181600       10       23        SP       1  817800
# 14       2019-12  73181600       10      249        SP       1  817800
# 21       2019-01  73182400       10      249        SC       1  927800
# 34       2019-01  73181600       10      386        SP       1  817800
# ...          ...       ...      ...      ...       ...     ...     ...
# 1763962  2019-08  73181500       10      275        MG       4  617700
# 1763977  2019-08  73182400       10      249        PR       4  817600
# 1764040  2019-08  73181500       10      249        SC       1  817800
# 1764114  2019-08  73181100       10      245        CE       4  317901
# 1764331  2019-08  73182300       10      805        SP       1  817800
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB  câmbio_mês_atual  câmbio_mês_anterior  \
# 8            1851        1851   70952          4.108924             4.154725
# 13          24296       24296  182720          4.108924             4.154725
# 14          27934       27934  349017          4.108924             4.154725
# 21             47          47    1767          3.741055             3.884405
# 34           8730        8730   76390          3.741055             3.884405
# ...           ...         ...     ...               ...                  ...
# 1763962        37          37    3452          4.019382             3.778713
# 1763977         1           1      48          4.019382             3.778713
# 1764040         2           2      46          4.019382             3.778713
# 1764114         3           3       1          4.019382             3.778713
# 1764331         4           4     106          4.019382             3.778713
#
#         POSIÇÃO_NCM
# 8              7318
# 13             7318
# 14             7318
# 21             7318
# 34             7318
# ...             ...
# 1763962        7318
# 1763977        7318
# 1764040        7318
# 1764114        7318
# 1764331        7318
#
# [34623 rows x 13 columns]

# %%
df1["CO_UNID"].value_counts()
# Out:
# 10    34623
# Name: CO_UNID, dtype: int64

# %%
df1.drop(columns="POSIÇÃO_NCM", inplace=True)
# Out:
# D:\ANACONDA\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1
# Out:
#          ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 8        2019-12  73181500       10       23        SP       4  817700
# 13       2019-12  73181600       10       23        SP       1  817800
# 14       2019-12  73181600       10      249        SP       1  817800
# 21       2019-01  73182400       10      249        SC       1  927800
# 34       2019-01  73181600       10      386        SP       1  817800
# ...          ...       ...      ...      ...       ...     ...     ...
# 1763962  2019-08  73181500       10      275        MG       4  617700
# 1763977  2019-08  73182400       10      249        PR       4  817600
# 1764040  2019-08  73181500       10      249        SC       1  817800
# 1764114  2019-08  73181100       10      245        CE       4  317901
# 1764331  2019-08  73182300       10      805        SP       1  817800
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB  câmbio_mês_atual  câmbio_mês_anterior
# 8            1851        1851   70952          4.108924             4.154725
# 13          24296       24296  182720          4.108924             4.154725
# 14          27934       27934  349017          4.108924             4.154725
# 21             47          47    1767          3.741055             3.884405
# 34           8730        8730   76390          3.741055             3.884405
# ...           ...         ...     ...               ...                  ...
# 1763962        37          37    3452          4.019382             3.778713
# 1763977         1           1      48          4.019382             3.778713
# 1764040         2           2      46          4.019382             3.778713
# 1764114         3           3       1          4.019382             3.778713
# 1764331         4           4     106          4.019382             3.778713
#
# [34623 rows x 12 columns]

# %%
# checando quais os códigos NCM mais recorrentes
g1=df1.groupby(['CO_NCM']).size().reset_index().rename(columns={0:'contagem'})
g1.sort_values(by=["contagem"],ascending=False)
# Out:
#       CO_NCM  contagem
# 4   73181500      9334
# 5   73181600      5493
# 11  73182900      5130
# 8   73182200      4230
# 6   73181900      2711
# 7   73182100      2434
# 10  73182400      2029
# 9   73182300      1320
# 3   73181400      1278
# 2   73181300       387
# 1   73181200       232
# 0   73181100        45

# %%
g1["% CO_NCM"] = g1["contagem"]/(g1["contagem"].sum())

# %%
g2=g1.sort_values(by=["contagem"],ascending=False)

# %%
g2["% CO_NCM ACUMUL"]=g2["% CO_NCM"].cumsum()

# %%
g2
# Out:
#       CO_NCM  contagem  % CO_NCM  % CO_NCM ACUMUL
# 4   73181500      9334  0.269590         0.269590
# 5   73181600      5493  0.158652         0.428241
# 11  73182900      5130  0.148167         0.576409
# 8   73182200      4230  0.122173         0.698582
# 6   73181900      2711  0.078301         0.776882
# 7   73182100      2434  0.070300         0.847183
# 10  73182400      2029  0.058603         0.905785
# 9   73182300      1320  0.038125         0.943910
# 3   73181400      1278  0.036912         0.980822
# 2   73181300       387  0.011178         0.992000
# 1   73181200       232  0.006701         0.998700
# 0   73181100        45  0.001300         1.000000

# %%
# tentando identificar um percentual que viabilize a implementação do modelo (considerando a necessidade de "dummizar" a variável CO_NCM, a ideia é reduzir o número de categorias)
g3=g2[g2["% CO_NCM ACUMUL"]<=0.95]
g3
# repare que 95% das ocorrências se restingem a 8 códigos NCM dentre os 12.
# Out:
#       CO_NCM  contagem  % CO_NCM  % CO_NCM ACUMUL
# 4   73181500      9334  0.269590         0.269590
# 5   73181600      5493  0.158652         0.428241
# 11  73182900      5130  0.148167         0.576409
# 8   73182200      4230  0.122173         0.698582
# 6   73181900      2711  0.078301         0.776882
# 7   73182100      2434  0.070300         0.847183
# 10  73182400      2029  0.058603         0.905785
# 9   73182300      1320  0.038125         0.943910

# %%
# os 5% que extrapolam o acumulado 95% serão agrupados em uma única categoria, portanto, segue a identificação desses valores:
g4=g2[g2["% CO_NCM ACUMUL"]>0.95]
g4
# Out:
#      CO_NCM  contagem  % CO_NCM  % CO_NCM ACUMUL
# 3  73181400      1278  0.036912         0.980822
# 2  73181300       387  0.011178         0.992000
# 1  73181200       232  0.006701         0.998700
# 0  73181100        45  0.001300         1.000000

# %%
# obtendo os 5% códigos NCM menos recorrentes, para agrupar como "outros" no df1 original
idx=g4["CO_NCM"]

# %%
mask=df1['CO_NCM'].isin(idx)
mask
# Out:
# 8          False
# 13         False
# 14         False
# 21         False
# 34         False
#            ...
# 1763962    False
# 1763977    False
# 1764040    False
# 1764114     True
# 1764331    False
# Name: CO_NCM, Length: 34623, dtype: bool

# %%
df1["CO_NCM_final"]=df1["CO_NCM"]
# Out:
# <ipython-input-19-e6965bd59fa8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["CO_NCM_final"]=df1["CO_NCM"]

# %%
# substituir os 5% NCM menos recorrentes pelo código 99999999 (alterou-se a coluna auxiliar CO_NCM_final para preservar a original CO_NCM)
df1.loc[mask, "CO_NCM_final"] = 99999999
# Out:
# D:\ANACONDA\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df1
# Out:
#          ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 8        2019-12  73181500       10       23        SP       4  817700
# 13       2019-12  73181600       10       23        SP       1  817800
# 14       2019-12  73181600       10      249        SP       1  817800
# 21       2019-01  73182400       10      249        SC       1  927800
# 34       2019-01  73181600       10      386        SP       1  817800
# ...          ...       ...      ...      ...       ...     ...     ...
# 1763962  2019-08  73181500       10      275        MG       4  617700
# 1763977  2019-08  73182400       10      249        PR       4  817600
# 1764040  2019-08  73181500       10      249        SC       1  817800
# 1764114  2019-08  73181100       10      245        CE       4  317901
# 1764331  2019-08  73182300       10      805        SP       1  817800
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB  câmbio_mês_atual  câmbio_mês_anterior  \
# 8            1851        1851   70952          4.108924             4.154725
# 13          24296       24296  182720          4.108924             4.154725
# 14          27934       27934  349017          4.108924             4.154725
# 21             47          47    1767          3.741055             3.884405
# 34           8730        8730   76390          3.741055             3.884405
# ...           ...         ...     ...               ...                  ...
# 1763962        37          37    3452          4.019382             3.778713
# 1763977         1           1      48          4.019382             3.778713
# 1764040         2           2      46          4.019382             3.778713
# 1764114         3           3       1          4.019382             3.778713
# 1764331         4           4     106          4.019382             3.778713
#
#          CO_NCM_final
# 8            73181500
# 13           73181600
# 14           73181600
# 21           73182400
# 34           73181600
# ...               ...
# 1763962      73181500
# 1763977      73182400
# 1764040      73181500
# 1764114      99999999
# 1764331      73182300
#
# [34623 rows x 13 columns]

# %%
df1["CO_NCM_final"].value_counts()
# Out:
# 73181500    9334
# 73181600    5493
# 73182900    5130
# 73182200    4230
# 73181900    2711
# 73182100    2434
# 73182400    2029
# 99999999    1942
# 73182300    1320
# Name: CO_NCM_final, dtype: int64

# %% [markdown]
# ###### Checando códigos UNID MED EST (CO_UNID) recorrentes

# %%
# A análise a seguir não se faz necessária, uma vez que todas as importações no âmbito da posição 7318 tem o quilograma (CO_UNID igual a 10) como unidade de medida estatística
#g1=df1.groupby(['CO_UNID']).size().reset_index().rename(columns={0:'contagem'})
#g1.sort_values(by=["contagem"],ascending=False)

# %%
df1["CO_UNID_final"]=df1["CO_UNID"]
# Out:
# <ipython-input-24-043d6a9cfec0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["CO_UNID_final"]=df1["CO_UNID"]

# %%
# no caso corrente não há CO_UNID minoritários para serem agrupados em categorial residual. Portanto, não se executará o código a seguir.
#mask=df1['CO_UNID']!=11
#mask

# %%
#df1.loc[mask, "CO_UNID_final"] = 99

# %%
df1["CO_UNID_final"].value_counts()
# Out:
# 10    34623
# Name: CO_UNID_final, dtype: int64

# %% [markdown]
# ###### Checando países (CO_PAIS) recorrentes

# %%
g1=df1.groupby(['CO_PAIS']).size().reset_index().rename(columns={0:'contagem'})
g1.sort_values(by=["contagem"],ascending=False)
# Out:
#      CO_PAIS  contagem
# 36       249      3913
# 21       160      3422
# 1         23      2927
# 53       386      2360
# 22       161      1667
# ..       ...       ...
# 67       507         1
# 69       528         1
# 83       625         1
# 73       566         1
# 110      890         1
#
# [111 rows x 2 columns]

# %%
g1["% CO_PAIS"] = g1["contagem"]/(g1["contagem"].sum())

# %%
g2=g1.sort_values(by=["contagem"],ascending=False)

# %%
g2["% CO_PAIS ACUMUL"]=g2["% CO_PAIS"].cumsum()

# %%
g2.head()
# Out:
#     CO_PAIS  contagem  % CO_PAIS  % CO_PAIS ACUMUL
# 36      249      3913   0.113017          0.113017
# 21      160      3422   0.098836          0.211853
# 1        23      2927   0.084539          0.296393
# 53      386      2360   0.068163          0.364555
# 22      161      1667   0.048147          0.412703

# %%
# tentando identificar um percentual que viabilize a implementação do modelo (considerando a necessidade de "dummizar" a variável CO_PAIS, a ideia é reduzir o número de categorias)
g3=g2[g2["% CO_PAIS ACUMUL"]<=0.95]
g3.info()
# repare que 95% das ocorrências se restingem a 33 países dentre os 111.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 36 to 93
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CO_PAIS           33 non-null     int64
#  1   contagem          33 non-null     int64
#  2   % CO_PAIS         33 non-null     float64
#  3   % CO_PAIS ACUMUL  33 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.3 KB

# %%
# os 5% que extrapolam o acumulado 95% serão agrupados em uma única categoria, portanto, segue a identificação desses valores:
g4=g2[g2["% CO_PAIS ACUMUL"]>0.95]
g4
# Out:
#      CO_PAIS  contagem  % CO_PAIS  % CO_PAIS ACUMUL
# 70       538       209   0.006036          0.950726
# 80       607       149   0.004303          0.955030
# 6         69       147   0.004246          0.959276
# 38       267       118   0.003408          0.962684
# 50       375        96   0.002773          0.965456
# ..       ...       ...        ...               ...
# 67       507         1   0.000029          0.999884
# 69       528         1   0.000029          0.999913
# 83       625         1   0.000029          0.999942
# 73       566         1   0.000029          0.999971
# 110      890         1   0.000029          1.000000
#
# [78 rows x 4 columns]

# %%
# obtendo os 5% países menos recorrentes, para agrupar como "outros" no df original
idx=g4["CO_PAIS"]

# %%
mask=df1['CO_PAIS'].isin(idx)
mask
# Out:
# 8          False
# 13         False
# 14         False
# 21         False
# 34         False
#            ...
# 1763962    False
# 1763977    False
# 1764040    False
# 1764114    False
# 1764331     True
# Name: CO_PAIS, Length: 34623, dtype: bool

# %%
df1["CO_PAIS_final"]=df1["CO_PAIS"]
# Out:
# <ipython-input-37-b9c243d6eb50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["CO_PAIS_final"]=df1["CO_PAIS"]

# %%
# substituir os 5% NCM menos recorrentes pelo código 99999999 (alterou-se a coluna auxiliar CO_PAIS_final para preservar a original CO_PAIS)
df1.loc[mask, "CO_PAIS_final"] = 999
# Out:
# D:\ANACONDA\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df1
# Out:
#          ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 8        2019-12  73181500       10       23        SP       4  817700
# 13       2019-12  73181600       10       23        SP       1  817800
# 14       2019-12  73181600       10      249        SP       1  817800
# 21       2019-01  73182400       10      249        SC       1  927800
# 34       2019-01  73181600       10      386        SP       1  817800
# ...          ...       ...      ...      ...       ...     ...     ...
# 1763962  2019-08  73181500       10      275        MG       4  617700
# 1763977  2019-08  73182400       10      249        PR       4  817600
# 1764040  2019-08  73181500       10      249        SC       1  817800
# 1764114  2019-08  73181100       10      245        CE       4  317901
# 1764331  2019-08  73182300       10      805        SP       1  817800
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB  câmbio_mês_atual  câmbio_mês_anterior  \
# 8            1851        1851   70952          4.108924             4.154725
# 13          24296       24296  182720          4.108924             4.154725
# 14          27934       27934  349017          4.108924             4.154725
# 21             47          47    1767          3.741055             3.884405
# 34           8730        8730   76390          3.741055             3.884405
# ...           ...         ...     ...               ...                  ...
# 1763962        37          37    3452          4.019382             3.778713
# 1763977         1           1      48          4.019382             3.778713
# 1764040         2           2      46          4.019382             3.778713
# 1764114         3           3       1          4.019382             3.778713
# 1764331         4           4     106          4.019382             3.778713
#
#          CO_NCM_final  CO_UNID_final  CO_PAIS_final
# 8            73181500             10             23
# 13           73181600             10             23
# 14           73181600             10            249
# 21           73182400             10            249
# 34           73181600             10            386
# ...               ...            ...            ...
# 1763962      73181500             10            275
# 1763977      73182400             10            249
# 1764040      73181500             10            249
# 1764114      99999999             10            245
# 1764331      73182300             10            999
#
# [34623 rows x 15 columns]

# %%
df1["CO_PAIS_final"].value_counts()
# Out:
# 249    3913
# 160    3422
# 23     2927
# 386    2360
# 999    1915
# 161    1667
# 399    1542
# 275    1463
# 190    1251
# 245    1155
# 628    1107
# 361    1066
# 764     987
# 149     798
# 767     643
# 791     643
# 573     627
# 776     625
# 827     609
# 271     606
# 72      604
# 232     565
# 493     553
# 603     536
# 87      447
# 63      374
# 858     348
# 365     326
# 105     275
# 455     274
# 351     268
# 355     263
# 247     249
# 741     215
# Name: CO_PAIS_final, dtype: int64

# %% [markdown]
# ###### Checando países (SG_UF_NCM) recorrentes

# %%
g1=df1.groupby(['SG_UF_NCM']).size().reset_index().rename(columns={0:'contagem'})
g1.sort_values(by=["contagem"],ascending=False)
# Out:
#    SG_UF_NCM  contagem
# 25        SP      8209
# 23        SC      3682
# 17        PR      3630
# 10        MG      3571
# 22        RS      3042
# 18        RJ      2812
# 2         AM      2636
# 4         BA      1742
# 13        PA      1080
# 5         CE       836
# 8         GO       817
# 15        PE       767
# 7         ES       547
# 11        MS       331
# 12        MT       169
# 19        RN       134
# 20        RO       127
# 1         AL       116
# 24        SE        91
# 16        PI        72
# 6         DF        67
# 9         MA        63
# 14        PB        50
# 26        TO        19
# 3         AP         8
# 0         AC         3
# 21        RR         2

# %%
g1["% SG_UF_NCM"] = g1["contagem"]/(g1["contagem"].sum())

# %%
g2=g1.sort_values(by=["contagem"],ascending=False)

# %%
g2["% SG_UF_NCM ACUMUL"]=g2["% SG_UF_NCM"].cumsum()

# %%
g2.head()
# Out:
#    SG_UF_NCM  contagem  % SG_UF_NCM  % SG_UF_NCM ACUMUL
# 25        SP      8209     0.237097            0.237097
# 23        SC      3682     0.106345            0.343442
# 17        PR      3630     0.104844            0.448286
# 10        MG      3571     0.103140            0.551425
# 22        RS      3042     0.087861            0.639286

# %%
# tentando identificar um percentual que viabilize a implementação do modelo (considerando a necessidade de "dummizar" a variável CO_NCM, a ideia é reduzir o número de categorias)
g3=g2[g2["% SG_UF_NCM ACUMUL"]<=0.95]
g3
# repare que 95% das ocorrências se restingem a 12 UF dentre as 27.
# Out:
#    SG_UF_NCM  contagem  % SG_UF_NCM  % SG_UF_NCM ACUMUL
# 25        SP      8209     0.237097            0.237097
# 23        SC      3682     0.106345            0.343442
# 17        PR      3630     0.104844            0.448286
# 10        MG      3571     0.103140            0.551425
# 22        RS      3042     0.087861            0.639286
# 18        RJ      2812     0.081218            0.720504
# 2         AM      2636     0.076134            0.796638
# 4         BA      1742     0.050313            0.846951
# 13        PA      1080     0.031193            0.878145
# 5         CE       836     0.024146            0.902290
# 8         GO       817     0.023597            0.925887
# 15        PE       767     0.022153            0.948040

# %%
# os 5% que extrapolam o acumulado 95% serão agrupados em uma única categoria, portanto, segue a identificação desses valores:
g4=g2[g2["% SG_UF_NCM ACUMUL"]>0.95]
g4
# Out:
#    SG_UF_NCM  contagem  % SG_UF_NCM  % SG_UF_NCM ACUMUL
# 7         ES       547     0.015799            0.963839
# 11        MS       331     0.009560            0.973399
# 12        MT       169     0.004881            0.978280
# 19        RN       134     0.003870            0.982151
# 20        RO       127     0.003668            0.985819
# 1         AL       116     0.003350            0.989169
# 24        SE        91     0.002628            0.991797
# 16        PI        72     0.002080            0.993877
# 6         DF        67     0.001935            0.995812
# 9         MA        63     0.001820            0.997632
# 14        PB        50     0.001444            0.999076
# 26        TO        19     0.000549            0.999625
# 3         AP         8     0.000231            0.999856
# 0         AC         3     0.000087            0.999942
# 21        RR         2     0.000058            1.000000

# %%
# obtendo os 5% UF menos recorrentes, para agrupar como "outros" no df original
idx=g4["SG_UF_NCM"]

# %%
mask=df1['SG_UF_NCM'].isin(idx)
mask
# Out:
# 8          False
# 13         False
# 14         False
# 21         False
# 34         False
#            ...
# 1763962    False
# 1763977    False
# 1764040    False
# 1764114    False
# 1764331    False
# Name: SG_UF_NCM, Length: 34623, dtype: bool

# %%
df1["SG_UF_NCM_final"]=df1["SG_UF_NCM"]
# Out:
# <ipython-input-50-dd95862fade3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["SG_UF_NCM_final"]=df1["SG_UF_NCM"]

# %%
# substituir os 5% NCM menos recorrentes pelo código 99 (alterou-se a coluna auxiliar SG_UF_NCM_final para preservar a original SG_UF_NCM)
df1.loc[mask, "SG_UF_NCM_final"] = 99
# Out:
# D:\ANACONDA\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df1
# Out:
#          ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 8        2019-12  73181500       10       23        SP       4  817700
# 13       2019-12  73181600       10       23        SP       1  817800
# 14       2019-12  73181600       10      249        SP       1  817800
# 21       2019-01  73182400       10      249        SC       1  927800
# 34       2019-01  73181600       10      386        SP       1  817800
# ...          ...       ...      ...      ...       ...     ...     ...
# 1763962  2019-08  73181500       10      275        MG       4  617700
# 1763977  2019-08  73182400       10      249        PR       4  817600
# 1764040  2019-08  73181500       10      249        SC       1  817800
# 1764114  2019-08  73181100       10      245        CE       4  317901
# 1764331  2019-08  73182300       10      805        SP       1  817800
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB  câmbio_mês_atual  câmbio_mês_anterior  \
# 8            1851        1851   70952          4.108924             4.154725
# 13          24296       24296  182720          4.108924             4.154725
# 14          27934       27934  349017          4.108924             4.154725
# 21             47          47    1767          3.741055             3.884405
# 34           8730        8730   76390          3.741055             3.884405
# ...           ...         ...     ...               ...                  ...
# 1763962        37          37    3452          4.019382             3.778713
# 1763977         1           1      48          4.019382             3.778713
# 1764040         2           2      46          4.019382             3.778713
# 1764114         3           3       1          4.019382             3.778713
# 1764331         4           4     106          4.019382             3.778713
#
#          CO_NCM_final  CO_UNID_final  CO_PAIS_final SG_UF_NCM_final
# 8            73181500             10             23              SP
# 13           73181600             10             23              SP
# 14           73181600             10            249              SP
# 21           73182400             10            249              SC
# 34           73181600             10            386              SP
# ...               ...            ...            ...             ...
# 1763962      73181500             10            275              MG
# 1763977      73182400             10            249              PR
# 1764040      73181500             10            249              SC
# 1764114      99999999             10            245              CE
# 1764331      73182300             10            999              SP
#
# [34623 rows x 16 columns]

# %%
df1["SG_UF_NCM_final"].value_counts()
# Out:
# SP    8209
# SC    3682
# PR    3630
# MG    3571
# RS    3042
# RJ    2812
# AM    2636
# 99    1799
# BA    1742
# PA    1080
# CE     836
# GO     817
# PE     767
# Name: SG_UF_NCM_final, dtype: int64

# %% [markdown]
# ###### Checando modais (CO_VIA) recorrentes

# %%
g1=df1.groupby(['CO_VIA']).size().reset_index().rename(columns={0:'contagem'})
g1.sort_values(by=["contagem"],ascending=False)
# Out:
#    CO_VIA  contagem
# 1       1     18207
# 2       4     15638
# 4       7       529
# 0       0       232
# 6      10         9
# 3       5         5
# 5       9         3

# %%
g1["% CO_VIA"] = g1["contagem"]/(g1["contagem"].sum())

# %%
g2=g1.sort_values(by=["contagem"],ascending=False)

# %%
g2["% CO_VIA ACUMUL"]=g2["% CO_VIA"].cumsum()

# %%
g2
# Out:
#    CO_VIA  contagem  % CO_VIA  % CO_VIA ACUMUL
# 1       1     18207  0.525864         0.525864
# 2       4     15638  0.451665         0.977529
# 4       7       529  0.015279         0.992808
# 0       0       232  0.006701         0.999509
# 6      10         9  0.000260         0.999769
# 3       5         5  0.000144         0.999913
# 5       9         3  0.000087         1.000000

# %%
df1["CO_VIA_final"]=df["CO_VIA"]
# Out:
# <ipython-input-59-0653cde63ffb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["CO_VIA_final"]=df["CO_VIA"]

# %%
mask=(df1['CO_VIA']!=1) & (df['CO_VIA']!=4) & (df['CO_VIA']!=7)
mask
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1764428    False
# 1764429    False
# 1764430    False
# 1764431    False
# 1764432    False
# Name: CO_VIA, Length: 1764433, dtype: bool

# %%
df1.loc[mask, "CO_VIA_final"] = 99
# Out:
# D:\ANACONDA\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df1["CO_VIA_final"].value_counts()
# Out:
# 1     18207
# 4     15638
# 7       529
# 99      249
# Name: CO_VIA_final, dtype: int64

# %% [markdown]
# ###### Não será levada em conta - inicialmente - a feature CO_URF, uma vez que essa está associada à SG_UF_NCM (que será "dummizada"). Posteriormente, pode-se substituir uma pela outra para ver se o modelo melhora.

# %% [markdown]
# ###### Na sequência, as colunas de features categóricas darão origem às variáveis dummie, para, posteriormente, calcular a correlação das colunas restantes com a variável alvo ( VL_FOB/QT_ESTAT)

# %%
df1["VL_FOB/QT_ESTAT"]=df1["VL_FOB"]/df1["QT_ESTAT"]
# Out:
# <ipython-input-63-0725dfbab52f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["VL_FOB/QT_ESTAT"]=df1["VL_FOB"]/df1["QT_ESTAT"]

# %%
df1.columns
# Out:
# Index(['ANO-MES', 'CO_NCM', 'CO_UNID', 'CO_PAIS', 'SG_UF_NCM', 'CO_VIA',
#        'CO_URF', 'QT_ESTAT', 'KG_LIQUIDO', 'VL_FOB', 'câmbio_mês_atual',
#        'câmbio_mês_anterior', 'CO_NCM_final', 'CO_UNID_final', 'CO_PAIS_final',
#        'SG_UF_NCM_final', 'CO_VIA_final', 'VL_FOB/QT_ESTAT'],
#       dtype='object')

# %%
df_encoded = pd.concat([df1, pd.get_dummies(df1["ANO-MES"],prefix="Mês")], axis=1)
df_encoded.head(3)
# Out:
#     ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  QT_ESTAT  \
# 8   2019-12  73181500       10       23        SP       4  817700      1851
# 13  2019-12  73181600       10       23        SP       1  817800     24296
# 14  2019-12  73181600       10      249        SP       1  817800     27934
#
#     KG_LIQUIDO  VL_FOB  ...  Mês_2019-03  Mês_2019-04  Mês_2019-05  \
# 8         1851   70952  ...            0            0            0
# 13       24296  182720  ...            0            0            0
# 14       27934  349017  ...            0            0            0
#
#     Mês_2019-06  Mês_2019-07 Mês_2019-08  Mês_2019-09  Mês_2019-10  \
# 8             0            0           0            0            0
# 13            0            0           0            0            0
# 14            0            0           0            0            0
#
#     Mês_2019-11  Mês_2019-12
# 8             0            1
# 13            0            1
# 14            0            1
#
# [3 rows x 30 columns]

# %%
df_encoded = pd.concat([df_encoded, pd.get_dummies(df_encoded["CO_NCM_final"],prefix="NCM")], axis=1)
df_encoded.head(3)
# Out:
#     ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  QT_ESTAT  \
# 8   2019-12  73181500       10       23        SP       4  817700      1851
# 13  2019-12  73181600       10       23        SP       1  817800     24296
# 14  2019-12  73181600       10      249        SP       1  817800     27934
#
#     KG_LIQUIDO  VL_FOB  ...  Mês_2019-12  NCM_73181500  NCM_73181600  \
# 8         1851   70952  ...            1             1             0
# 13       24296  182720  ...            1             0             1
# 14       27934  349017  ...            1             0             1
#
#     NCM_73181900  NCM_73182100 NCM_73182200  NCM_73182300  NCM_73182400  \
# 8              0             0            0             0             0
# 13             0             0            0             0             0
# 14             0             0            0             0             0
#
#     NCM_73182900  NCM_99999999
# 8              0             0
# 13             0             0
# 14             0             0
#
# [3 rows x 39 columns]

# %%
df_encoded = pd.concat([df_encoded, pd.get_dummies(df_encoded["CO_UNID_final"],prefix="Un.Med.Est.")], axis=1)
df_encoded.head(3)
# Out:
#     ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  QT_ESTAT  \
# 8   2019-12  73181500       10       23        SP       4  817700      1851
# 13  2019-12  73181600       10       23        SP       1  817800     24296
# 14  2019-12  73181600       10      249        SP       1  817800     27934
#
#     KG_LIQUIDO  VL_FOB  ...  NCM_73181500  NCM_73181600  NCM_73181900  \
# 8         1851   70952  ...             1             0             0
# 13       24296  182720  ...             0             1             0
# 14       27934  349017  ...             0             1             0
#
#     NCM_73182100  NCM_73182200 NCM_73182300  NCM_73182400  NCM_73182900  \
# 8              0             0            0             0             0
# 13             0             0            0             0             0
# 14             0             0            0             0             0
#
#     NCM_99999999  Un.Med.Est._10
# 8              0               1
# 13             0               1
# 14             0               1
#
# [3 rows x 40 columns]

# %%
df_encoded = pd.concat([df_encoded, pd.get_dummies(df_encoded["CO_PAIS_final"],prefix="Pais")], axis=1)
df_encoded.head(3)
# Out:
#     ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  QT_ESTAT  \
# 8   2019-12  73181500       10       23        SP       4  817700      1851
# 13  2019-12  73181600       10       23        SP       1  817800     24296
# 14  2019-12  73181600       10      249        SP       1  817800     27934
#
#     KG_LIQUIDO  VL_FOB  ...  Pais_603  Pais_628  Pais_741  Pais_764  Pais_767  \
# 8         1851   70952  ...         0         0         0         0         0
# 13       24296  182720  ...         0         0         0         0         0
# 14       27934  349017  ...         0         0         0         0         0
#
#    Pais_776  Pais_791  Pais_827  Pais_858  Pais_999
# 8         0         0         0         0         0
# 13        0         0         0         0         0
# 14        0         0         0         0         0
#
# [3 rows x 74 columns]

# %%
df_encoded = pd.concat([df_encoded, pd.get_dummies(df_encoded["SG_UF_NCM_final"],prefix="UF")], axis=1)
df_encoded.head(3)
# Out:
#     ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  QT_ESTAT  \
# 8   2019-12  73181500       10       23        SP       4  817700      1851
# 13  2019-12  73181600       10       23        SP       1  817800     24296
# 14  2019-12  73181600       10      249        SP       1  817800     27934
#
#     KG_LIQUIDO  VL_FOB  ...  UF_CE  UF_GO  UF_MG  UF_PA  UF_PE UF_PR  UF_RJ  \
# 8         1851   70952  ...      0      0      0      0      0     0      0
# 13       24296  182720  ...      0      0      0      0      0     0      0
# 14       27934  349017  ...      0      0      0      0      0     0      0
#
#     UF_RS  UF_SC  UF_SP
# 8       0      0      1
# 13      0      0      1
# 14      0      0      1
#
# [3 rows x 87 columns]

# %%
df_encoded = pd.concat([df_encoded, pd.get_dummies(df_encoded["CO_VIA_final"],prefix="Modal")], axis=1)
df_encoded.head(3)
# Out:
#     ANO-MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  QT_ESTAT  \
# 8   2019-12  73181500       10       23        SP       4  817700      1851
# 13  2019-12  73181600       10       23        SP       1  817800     24296
# 14  2019-12  73181600       10      249        SP       1  817800     27934
#
#     KG_LIQUIDO  VL_FOB  ...  UF_PE  UF_PR  UF_RJ  UF_RS  UF_SC UF_SP  Modal_1  \
# 8         1851   70952  ...      0      0      0      0      0     1        0
# 13       24296  182720  ...      0      0      0      0      0     1        1
# 14       27934  349017  ...      0      0      0      0      0     1        1
#
#     Modal_4  Modal_7  Modal_99
# 8         1        0         0
# 13        0        0         0
# 14        0        0         0
#
# [3 rows x 91 columns]

# %%
# Exclusão das colunas das variáveis categóricas (que deram origem às variáveis dummie)
df_encoded = df_encoded.drop(columns=['ANO-MES', 'CO_NCM', 'CO_UNID', 'CO_PAIS', 'SG_UF_NCM', 'CO_VIA',
       'CO_URF', 'KG_LIQUIDO', 'VL_FOB', 'CO_NCM_final', 'CO_UNID_final', 'CO_PAIS_final',
       'SG_UF_NCM_final', 'CO_VIA_final'])

# %%
df_encoded.columns
# Out:
# Index(['QT_ESTAT', 'câmbio_mês_atual', 'câmbio_mês_anterior',
#        'VL_FOB/QT_ESTAT', 'Mês_2019-01', 'Mês_2019-02', 'Mês_2019-03',
#        'Mês_2019-04', 'Mês_2019-05', 'Mês_2019-06', 'Mês_2019-07',
#        'Mês_2019-08', 'Mês_2019-09', 'Mês_2019-10', 'Mês_2019-11',
#        'Mês_2019-12', 'NCM_73181500', 'NCM_73181600', 'NCM_73181900',
#        'NCM_73182100', 'NCM_73182200', 'NCM_73182300', 'NCM_73182400',
#        'NCM_73182900', 'NCM_99999999', 'Un.Med.Est._10', 'Pais_23', 'Pais_63',
#        'Pais_72', 'Pais_87', 'Pais_105', 'Pais_149', 'Pais_160', 'Pais_161',
#        'Pais_190', 'Pais_232', 'Pais_245', 'Pais_247', 'Pais_249', 'Pais_271',
#        'Pais_275', 'Pais_351', 'Pais_355', 'Pais_361', 'Pais_365', 'Pais_386',
#        'Pais_399', 'Pais_455', 'Pais_493', 'Pais_573', 'Pais_603', 'Pais_628',
#        'Pais_741', 'Pais_764', 'Pais_767', 'Pais_776', 'Pais_791', 'Pais_827',
#        'Pais_858', 'Pais_999', 'UF_99', 'UF_AM', 'UF_BA', 'UF_CE', 'UF_GO',
#        'UF_MG', 'UF_PA', 'UF_PE', 'UF_PR', 'UF_RJ', 'UF_RS', 'UF_SC', 'UF_SP',
#        'Modal_1', 'Modal_4', 'Modal_7', 'Modal_99'],
#       dtype='object')

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34623 entries, 8 to 1764331
# Data columns (total 77 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   QT_ESTAT             34623 non-null  int64
#  1   câmbio_mês_atual     34623 non-null  float64
#  2   câmbio_mês_anterior  34623 non-null  float64
#  3   VL_FOB/QT_ESTAT      34623 non-null  float64
#  4   Mês_2019-01          34623 non-null  uint8
#  5   Mês_2019-02          34623 non-null  uint8
#  6   Mês_2019-03          34623 non-null  uint8
#  7   Mês_2019-04          34623 non-null  uint8
#  8   Mês_2019-05          34623 non-null  uint8
#  9   Mês_2019-06          34623 non-null  uint8
#  10  Mês_2019-07          34623 non-null  uint8
#  11  Mês_2019-08          34623 non-null  uint8
#  12  Mês_2019-09          34623 non-null  uint8
#  13  Mês_2019-10          34623 non-null  uint8
#  14  Mês_2019-11          34623 non-null  uint8
#  15  Mês_2019-12          34623 non-null  uint8
#  16  NCM_73181500         34623 non-null  uint8
#  17  NCM_73181600         34623 non-null  uint8
#  18  NCM_73181900         34623 non-null  uint8
#  19  NCM_73182100         34623 non-null  uint8
#  20  NCM_73182200         34623 non-null  uint8
#  21  NCM_73182300         34623 non-null  uint8
#  22  NCM_73182400         34623 non-null  uint8
#  23  NCM_73182900         34623 non-null  uint8
#  24  NCM_99999999         34623 non-null  uint8
#  25  Un.Med.Est._10       34623 non-null  uint8
#  26  Pais_23              34623 non-null  uint8
#  27  Pais_63              34623 non-null  uint8
#  28  Pais_72              34623 non-null  uint8
#  29  Pais_87              34623 non-null  uint8
#  30  Pais_105             34623 non-null  uint8
#  31  Pais_149             34623 non-null  uint8
#  32  Pais_160             34623 non-null  uint8
#  33  Pais_161             34623 non-null  uint8
#  34  Pais_190             34623 non-null  uint8
#  35  Pais_232             34623 non-null  uint8
#  36  Pais_245             34623 non-null  uint8
#  37  Pais_247             34623 non-null  uint8
#  38  Pais_249             34623 non-null  uint8
#  39  Pais_271             34623 non-null  uint8
#  40  Pais_275             34623 non-null  uint8
#  41  Pais_351             34623 non-null  uint8
#  42  Pais_355             34623 non-null  uint8
#  43  Pais_361             34623 non-null  uint8
#  44  Pais_365             34623 non-null  uint8
#  45  Pais_386             34623 non-null  uint8
#  46  Pais_399             34623 non-null  uint8
#  47  Pais_455             34623 non-null  uint8
#  48  Pais_493             34623 non-null  uint8
#  49  Pais_573             34623 non-null  uint8
#  50  Pais_603             34623 non-null  uint8
#  51  Pais_628             34623 non-null  uint8
#  52  Pais_741             34623 non-null  uint8
#  53  Pais_764             34623 non-null  uint8
#  54  Pais_767             34623 non-null  uint8
#  55  Pais_776             34623 non-null  uint8
#  56  Pais_791             34623 non-null  uint8
#  57  Pais_827             34623 non-null  uint8
#  58  Pais_858             34623 non-null  uint8
#  59  Pais_999             34623 non-null  uint8
#  60  UF_99                34623 non-null  uint8
#  61  UF_AM                34623 non-null  uint8
#  62  UF_BA                34623 non-null  uint8
#  63  UF_CE                34623 non-null  uint8
#  64  UF_GO                34623 non-null  uint8
#  65  UF_MG                34623 non-null  uint8
#  66  UF_PA                34623 non-null  uint8
#  67  UF_PE                34623 non-null  uint8
#  68  UF_PR                34623 non-null  uint8
#  69  UF_RJ                34623 non-null  uint8
#  70  UF_RS                34623 non-null  uint8
#  71  UF_SC                34623 non-null  uint8
#  72  UF_SP                34623 non-null  uint8
#  73  Modal_1              34623 non-null  uint8
#  74  Modal_4              34623 non-null  uint8
#  75  Modal_7              34623 non-null  uint8
#  76  Modal_99             34623 non-null  uint8
# dtypes: float64(3), int64(1), uint8(73)
# memory usage: 5.0 MB

# %%
# Identificação das variáveis que mais se relacionam com a variável alvo ("VL_FOB/QT_ESTAT")
correlacoes = df_encoded.corr().abs()["VL_FOB/QT_ESTAT"].sort_values(ascending=False)
correlacoes.head(20)
# Out:
# VL_FOB/QT_ESTAT    1.000000
# Modal_1            0.176811
# Modal_4            0.172540
# Pais_249           0.078622
# Pais_275           0.075753
# UF_RJ              0.061235
# Pais_160           0.060483
# UF_CE              0.060434
# Modal_99           0.046090
# Pais_767           0.041084
# UF_RS              0.041073
# NCM_99999999       0.040084
# NCM_73182900       0.033370
# Pais_161           0.032915
# QT_ESTAT           0.032475
# Pais_190           0.031134
# Pais_628           0.030865
# UF_SC              0.030029
# Pais_361           0.028063
# NCM_73182200       0.026453
# Name: VL_FOB/QT_ESTAT, dtype: float64

# %%
# Identificando as features com as maiores correlações (maior ou igual a 0,01) para serem mantidas e excluídas as demais
(correlacoes[correlacoes >= 0.03]).index
# Out:
# Index(['VL_FOB/QT_ESTAT', 'Modal_1', 'Modal_4', 'Pais_249', 'Pais_275',
#        'UF_RJ', 'Pais_160', 'UF_CE', 'Modal_99', 'Pais_767', 'UF_RS',
#        'NCM_99999999', 'NCM_73182900', 'Pais_161', 'QT_ESTAT', 'Pais_190',
#        'Pais_628', 'UF_SC'],
#       dtype='object')

# %%
# Selecionando as features com as maiores correlações (maior ou igual a 0,01) para serem mantidas e excluídas as demais
df2 = df_encoded[(correlacoes[correlacoes >= 0.03]).index]

# %%
#Checar se existe correlação entre as features selecionadas
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.heatmap(df2.corr(),cmap="coolwarm", annot=False)
# Out:
# <AxesSubplot:>

# %%
#Considerando que as Modal_1 e Modal_4 estão fortemente relacionadas, irei retirar uma delas antes da elaboração do modelo
df2=df2.drop(columns="Modal_1")

# %% [markdown]
# # Dividindo o dataset em "base de teste" e "base de treinamento"

# %%
df2.columns
# Out:
# Index(['VL_FOB/QT_ESTAT', 'Modal_4', 'Pais_249', 'Pais_275', 'UF_RJ',
#        'Pais_160', 'UF_CE', 'Modal_99', 'Pais_767', 'UF_RS', 'NCM_99999999',
#        'NCM_73182900', 'Pais_161', 'QT_ESTAT', 'Pais_190', 'Pais_628',
#        'UF_SC'],
#       dtype='object')

# %%
x = df2[['Modal_4', 'Pais_249', 'Pais_275', 'UF_RJ',
       'Pais_160', 'UF_CE', 'Modal_99', 'Pais_767', 'UF_RS', 'NCM_99999999',
       'NCM_73182900', 'Pais_161', 'QT_ESTAT', 'Pais_190', 'Pais_628',
       'UF_SC']]
y = df2['VL_FOB/QT_ESTAT']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=16)

# %% [markdown]
# # Treinando o modelo LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# impressão do intercepto
print(lm.intercept_)
# Out:
# 12.179832484226111

# %%
# impressão dos coeficientes
coeff_df = pd.DataFrame(lm.coef_,x.columns,columns=['Coeficiente'])
coeff_df
# Out:
#               Coeficiente
# Modal_4        149.131572
# Pais_249       101.808579
# Pais_275       189.319652
# UF_RJ           85.507436
# Pais_160       -48.376652
# UF_CE          226.971428
# Modal_99       258.384300
# Pais_767       129.667192
# UF_RS          -38.452515
# NCM_99999999   -24.051865
# NCM_73182900    37.210846
# Pais_161       -33.993787
# QT_ESTAT         0.000005
# Pais_190       -46.553241
# Pais_628        83.248894
# UF_SC           -3.745051

# %%
# realizando as predições
predicoesLR = lm.predict(x_test)

# %% [markdown]
# # Treinando o modelo Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=100)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
predicoesRFR = rfr.predict(x_test)

# %% [markdown]
# # Treinando o modelo Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
predicoesGBR = gbr.predict(x_test)

# %% [markdown]
# # Avaliando os modelos

# %% [markdown]
# #### Root mean squared error - RMSE

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
def rmse(y_true, y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

# %%
RMSE_LR = rmse(y_test,predicoesLR)
RMSE_LR
# Out:
# 357.5010140187652

# %%
RMSE_RFR = rmse(y_test,predicoesRFR)
RMSE_RFR
# Out:
# 362.3815706908542

# %%
RMSE_GBR = rmse(y_test,predicoesGBR)
RMSE_GBR
# Out:
# 352.0015836710883

# %% [markdown]
# #### Mean absolute error - MAE

# %%
from sklearn.metrics import mean_absolute_error

# %%
MAE_LR=mean_absolute_error(y_test, predicoesLR)
MAE_LR
# Out:
# 134.8944492137485

# %%
MAE_RFR=mean_absolute_error(y_test, predicoesRFR)
MAE_RFR
# Out:
# 117.47799084174089

# %%
MAE_GBR=mean_absolute_error(y_test, predicoesGBR)
MAE_GBR
# Out:
# 118.9522900081449

# %% [markdown]
# #### Mean squared error - MSE

# %%
from sklearn.metrics import mean_absolute_error

# %%
MSE_LR=mean_squared_error(y_test, predicoesLR)
MSE_LR
# Out:
# 127806.97502444535

# %%
MSE_RFR=mean_squared_error(y_test, predicoesRFR)
MSE_RFR
# Out:
# 131320.40277637052

# %%
MSE_GBR=mean_squared_error(y_test, predicoesGBR)
MSE_GBR
# Out:
# 123905.11490695419

# %% [markdown]
# #### Coeficente de determinação - R²

# %%
from sklearn.metrics import r2_score

# %%
R2_LR=r2_score(y_test, predicoesLR)
R2_LR
# Out:
# 0.04302370316224158

# %%
R2_RFR=r2_score(y_test, predicoesRFR)
R2_RFR
# Out:
# 0.01671631987113964

# %%
R2_GBR=r2_score(y_test, predicoesGBR)
R2_GBR
# Out:
# 0.07223953935037941
